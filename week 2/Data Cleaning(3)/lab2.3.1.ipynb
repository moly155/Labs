# %% [markdown]
# # Challenge 1

# %%
import pandas as pd

df = pd.read_csv('lab2.3.1.csv')
df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
df.columns = [col.replace(' ', '_').lower() for col in df.columns]
df
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
def convert(cell):
    if str(cell)=='nan':
        return str(cell)
    else:
        return float(cell.replace('%',''))

# %%
df['customer_lifetime_value'] = df['customer_lifetime_value'].apply(convert)
df
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        nan      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %%
def sex(cell):
    if 'f' in str(cell).lower():
        return 'F'
    elif 'm' in str(cell).lower():
        return 'M'
    else:
        return cell 
    

df.gender = df.gender.apply(sex)
df
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        nan      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %%
df.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
df.customer_lifetime_value = df.customer_lifetime_value.astype(float)
df.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
df = df.dropna(how='all')
df
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
mean = df.customer_lifetime_value.mean()

df['customer_lifetime_value'].fillna(mean, inplace=True)

df
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# ...

# %%
# si la suma de los booleans s 0, todos los valores son False, por lo tanto, no hay linias duplicadas 

df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Challenge 2

# %%
x = pd.read_csv('lab2.3.1.csv')
x
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
def clean(df):
    df.columns = [col.replace(' ', '_').lower() for col in df.columns]

    def convert(cell):
        if str(cell)=='nan':
            return str(cell)
        else:
            return float(cell.replace('%',''))
        
    df['customer_lifetime_value'] = df['customer_lifetime_value'].apply(convert)

    def sex(cell):
        if 'f' in str(cell).lower():
            return 'F'
        elif 'm' in str(cell).lower():
            return 'M'
        else:
            return cell 
    

    df.gender = df.gender.apply(sex)

    df.customer_lifetime_value = df.customer_lifetime_value.astype(float)
    
    df = df.dropna(how='all')

    mean = df.customer_lifetime_value.mean()

    df['customer_lifetime_value'].fillna(mean, inplace=True)


    return df

# %%
clean(x)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# ...

# %% [markdown]
# # Challenge 3

# %%
df.customer_lifetime_value.describe()
# Out:
# count    1.071000e+03
# mean     7.936903e+05
# std      6.425757e+05
# min      2.004351e+05
# 25%      4.048535e+05
# 50%      5.887182e+05
# 75%      8.945210e+05
# max      5.816655e+06
# Name: customer_lifetime_value, dtype: float64

# %%
df.total_claim_amount.describe()
# Out:
# count    1071.000000
# mean      404.986909
# std       293.027260
# min         0.382107
# 25%       202.157702
# 50%       354.729129
# 75%       532.800000
# max      2893.239678
# Name: total_claim_amount, dtype: float64

# %%
selection = (df.total_claim_amount >df.total_claim_amount.quantile(0.75)) & (df.customer_lifetime_value<df.customer_lifetime_value.quantile(0.25) )
bad_customers = df[selection]
bad_customers
# Out:
#      customer          st gender             education  \
# 17    OE15005        Cali    NaN               College
# 23    TZ98966      Nevada    NaN              Bachelor
# 26    US89481  California    NaN              Bachelor
# 38    CM61827      Oregon    NaN              Bachelor
# 42    IL19217  California    NaN              Bachelor
# 62    FG63582      Oregon    NaN              Bachelor
# 135   MS41162          AZ    NaN  High School or Below
# 140   DS81757      Oregon      M               College
# 158   KA61892     Arizona      M               College
# 160   ND87334  California      M  High School or Below
# 170   TS19868  California      M               College
# 184   AB13432  California      M              Bachelor
# 204   FL34139  California      M  High School or Below
# 250   IA63417     Arizona      F  High School or Below
# 269   VZ51506     Arizona      F  High School or Below
# 279   OH60605      Oregon      F  High School or Below
# ...

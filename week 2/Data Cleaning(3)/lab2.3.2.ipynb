# %%
import pandas as pd

# %%
df1 = pd.read_csv('lab2.3.1.csv')
df2 = pd.read_csv('file2.csv')
df3 = pd.read_csv('file3.csv')

# %%
def clean(df):
    df.columns = [col.replace(' ', '_').lower() for col in df.columns]

    def convert(cell):
        if str(cell)=='nan':
            return str(cell)
        else:
            return float(cell.replace('%',''))
        
    df['customer_lifetime_value'] = df['customer_lifetime_value'].apply(convert)

    def sex(cell):
        if 'f' in str(cell).lower():
            return 'F'
        elif 'm' in str(cell).lower():
            return 'M'
        else:
            return cell 
    

    df.gender = df.gender.apply(sex)

    df.customer_lifetime_value = df.customer_lifetime_value.astype(float)
    
    df = df.dropna(how='all')

    mean = df.customer_lifetime_value.mean()

    df['customer_lifetime_value'].fillna(mean, inplace=True)


    return df

# %%
df1 = clean(df1)
df1
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# ...

# %%
df2 = clean(df2)
df2
# Out:
#     customer          st gender education  customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor                323912.47   16061
# 1    CW49887  California      F    Master                462680.11   79487
# 2    MY31220  California      F   College                899704.02   54230
# 3    UH35128      Oregon      F   College               2580706.30   71210
# 4    WH52799     Arizona      F   College                380812.21   94903
# ..       ...         ...    ...       ...                      ...     ...
# 991  HV85198     Arizona      M    Master                847141.75   63513
# 992  BS91566     Arizona      F   College                543121.91   58161
# 993  IL40123      Nevada      F   College                568964.41   83640
# 994  MY32149  California      F    Master                368672.38       0
# 995  SA91515  California      M  Bachelor                399258.39       0
#
# ...

# %%
df3.columns = [col.replace(' ', '_').lower() for col in df3.columns]
df3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
def sex(cell):
        if 'f' in str(cell).lower():
            return 'F'
        elif 'm' in str(cell).lower():
            return 'M'
        else:
            return cell 
    

df3.gender = df3.gender.apply(sex)
df3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
df1 = df1.sort_values('customer')
df2 = df2.sort_values('customer')
df3 = df3.sort_values('customer')

df1
# Out:
#     customer          st gender             education  \
# 948  AA71604     Arizona      F                Master
# 184  AB13432  California      M              Bachelor
# 960  AB60627        Cali      M  High School or Below
# 175  AB72731  California      F              Bachelor
# 101  AB96670  California    NaN               College
# ..       ...         ...    ...                   ...
# 518  ZX23819      Oregon      F  High School or Below
# 203  ZX64745  California      M               College
# 812  ZX86243     Arizona      M                Doctor
# 625  ZZ91716  California      F              Bachelor
# 522  ZZ97035  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 948               1198659.21  87560.0                  98.0
# 184                373583.81      0.0                 110.0
# 960               1546778.90  77517.0                 129.0
# 175                463998.16  28358.0                 117.0
# ...

# %%
df2
# Out:
#     customer          st gender             education  \
# 350  AB21519  California      F               College
# 435  AC22873     Arizona      F  High School or Below
# 202  AC75391     Arizona      F               College
# 72   AF81450  California      M  High School or Below
# 186  AG22225      Oregon      M  High School or Below
# ..       ...         ...    ...                   ...
# 600  ZY20779  Washington      M  High School or Below
# 874  ZY33234      Nevada      F  High School or Below
# 89   ZY99878  California      M  High School or Below
# 265  ZZ44902     Arizona      M  High School or Below
# 99   ZZ83340      Oregon      F                Doctor
#
#      customer_lifetime_value  income  monthly_premium_auto  \
# 350                386148.63   93272                    95
# 435                485310.03   17120                   125
# 202                576809.13   35091                    74
# 72                1143173.09   28657                   100
# ...

# %%
merged_df = pd.merge(df1, pd.merge(df2, df3, on='customer', how='outer'), on='customer', how='outer')
merged_df
# Out:
#      customer        st_x gender             education  \
# 0     AA71604     Arizona      F                Master
# 1     AB13432  California      M              Bachelor
# 2     AB60627        Cali      M  High School or Below
# 3     AB72731  California      F              Bachelor
# 4     AB96670  California    NaN               College
# ...       ...         ...    ...                   ...
# 9051  ZZ62245         NaN    NaN                   NaN
# 9052  ZZ68210         NaN    NaN                   NaN
# 9053  ZZ69693         NaN    NaN                   NaN
# 9054  ZZ77357         NaN    NaN                   NaN
# 9055  ZZ89380         NaN    NaN                   NaN
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                  1198659.21  87560.0                  98.0
# 1                   373583.81      0.0                 110.0
# 2                  1546778.90  77517.0                 129.0
# ...

# %%
mkt = pd.read_csv('marketing_customer_analysis.csv')
mkt.columns = [col.replace(' ', '_').lower() for col in mkt.columns]
mkt.sort_values('customer')
mkt.drop_duplicates()
mkt.dropna(how='all')
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
import datetime

mkt['effective_to_date'] = pd.to_datetime(mkt['effective_to_date'])
mkt.dtypes
# Out:
# unnamed:_0                                int64
# customer                                 object
# state                                    object
# customer_lifetime_value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective_to_date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location_code                            object
# marital_status                           object
# monthly_premium_auto                      int64
# months_since_last_claim                 float64
# months_since_policy_inception             int64
# number_of_open_complaints               float64
# number_of_policies                        int64
# policy_type                              object
# policy                                   object
# ...

# %%
mkt['month'] = mkt['effective_to_date'].dt.month
mkt
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
mkt.month ==3
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10905    False
# 10906    False
# 10907    False
# 10908    False
# 10909    False
# Name: month, Length: 10910, dtype: bool

# %%
# save a clean dataset into a csv file 

mkt.to_csv('clean.csv', index=False)

# %%
# Out:
#                unnamed:_0  customer  state  customer_lifetime_value  response  \
# sales_channel
# Agent                4121      4121   3890                     4121      3890
# Branch               3022      3022   2865                     3022      2865
# Call Center          2141      2141   2013                     2141      2013
# Web                  1626      1626   1511                     1626      1511
#
#                coverage  education  effective_to_date  employmentstatus  \
# sales_channel
# Agent              4121       4121               4121              4121
# Branch             3022       3022               3022              3022
# Call Center        2141       2141               2141              2141
# Web                1626       1626               1626              1626
#
#                gender  ...  number_of_open_complaints  number_of_policies  \
# sales_channel          ...
# Agent            4121  ...                       3887                4121
# ...

# %%
mkt.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type', 'month'],
#       dtype='object')

# %%
mkt['total_revenue'] = round((mkt.income)-(mkt.total_claim_amount),2)

# %%
sorted_mkt = mkt.groupby('sales_channel')['total_revenue'].sum().reset_index().sort_values(by='total_revenue', ascending=False)
sorted_mkt
# Out:
#   sales_channel  total_revenue
# 0         Agent   1.506799e+08
# 1        Branch   1.124744e+08
# 2   Call Center   8.012840e+07
# 3           Web   6.149350e+07

# %%
average_clv = mkt.groupby(['gender', 'education'])['customer_lifetime_value'].mean().reset_index()
average_clv
# Out:
#   gender             education  customer_lifetime_value
# 0      F              Bachelor              7874.269478
# 1      F               College              7748.823325
# 2      F                Doctor              7328.508916
# 3      F  High School or Below              8675.220201
# 4      F                Master              8157.053154
# 5      M              Bachelor              7703.601675
# 6      M               College              8052.459288
# 7      M                Doctor              7415.333638
# 8      M  High School or Below              8149.687783
# 9      M                Master              8168.832659

# %%
highest_complaints = mkt.groupby(['month', 'policy_type'])['total_claim_amount'].count().reset_index()

highest_complaints_sorted = highest_complaints.sort_values(by='total_claim_amount', ascending=False)
highest_complaints_sorted
# Out:
#    month     policy_type  total_claim_amount
# 1      1   Personal Auto                4329
# 4      2   Personal Auto                3799
# 0      1  Corporate Auto                1252
# 3      2  Corporate Auto                1089
# 2      1    Special Auto                 237
# 5      2    Special Auto                 204
